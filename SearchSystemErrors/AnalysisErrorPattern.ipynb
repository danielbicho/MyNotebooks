# %%
import numpy as np
import pandas as pd
import matplotlib as plt
# %matplotlib inline

# %%
df = pd.read_csv('test_errors', sep=' ', names = ['error','1','2','requests','3','4'])

# %%
df = df[['error','requests']]

# %%
df.groupby(['requests']).mean().plot()

# %%
df.groupby(['requests']).max().plot()
